# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import MarkerCluster

# %%
data = pd.read_csv('data/Parcels.csv')

# %%
data1 = pd.read_csv('xxx.csv')
data1.dtypes
# Out:
# ZIP      int64
# LAT    float64
# LNG    float64
# dtype: object

# %%
#merge lat and lng data set
#data = data.merge(data1, left_on='ZIPNUM', right_on='ZIP')

#Drop missing zip codes and sales price
data = data.replace({'ZIPNUM': '0'}, np.nan)
dropped_zip = data.dropna(subset=['ZIPNUM'])
dropped_zip = dropped_zip.dropna(subset=['TOTSALPRICE'])


#Looking at only residential data and sales after 2019
dropped_zip = dropped_zip.loc[dropped_zip['LAND_CLASS_DECODE'] == 'Residential Less Than 10 Acres']
dropped_zip = dropped_zip.loc[dropped_zip['DEED_DATE'] > '2019/01/01 00:00:00+00']
dropped_zip
# Out:
#         OBJECTID       PIN_NUM  CALC_AREA      REID MAP_NAME  \
# 20      53227838  7.216807e+08   0.205975  232477.0  0721 02
# 53      53227871  6.678627e+08   0.358558  276306.0  0667 02
# 62      53227880  7.705613e+08   0.743761  286469.0  0770 02
# 90      53227908  6.499775e+08   0.103309  319468.0  0649 02
# 91      53227909  1.749642e+09   0.952026   88484.0  1749 04
# ...          ...           ...        ...       ...      ...
# 379380  53607288  6.563228e+08   0.185605  464986.0  0656 03
# 379382  53607290  6.563330e+08   0.162533  464971.0  0656 03
# 379384  53607292  6.563333e+08   0.162530  464955.0  0656 03
# 379449  53607357  1.704966e+09   0.168436  465789.0  1704 12
# 379450  53607358  1.704967e+09   0.179453  465788.0  1704 12
#
#                                                     OWNER  \
# 20                                       GASPER, TAMMI L
# 53                       MENTRUP, MICHAEL MENTRUP, CHELSE
# 62                              BIJLANI, ROBIN VINCI, JOY
# 90            ELMZOUDI, ABDELKEBIR YASSINE RANDOUR, IIHAM
# 91                             HILL, DANIEL M HILL, SUE K
# ...                                                   ...
# 379380                                   HIA, KYLE JAMES
# 379382  SCHWARZWELLER, THOMAS CHRISTOPHER SCHWARZWELLE...
# 379384            WARE, ZACHARY THOMAS WARE, CORIE WATSON
# 379449      GARNER, SAMUEL MICHAEL R GARNER, JESSICA ANNE
# 379450                                   BARRORD, JOHN V
#
#                         ADDR1                        ADDR2 ADDR3 DEED_BOOK  \
# 20             406 BERGEN AVE           APEX NC 27502-4852   NaN    017447
# 53           1628 MCLAURIN LN  FUQUAY VARINA NC 27526-9406   NaN    017801
# 62      3212 HIGH LONESOME LN           APEX NC 27539-5606   NaN    017405
# 90             108 SANCHEZ CT  HOLLY SPRINGS NC 27540-9440   NaN    017603
# 91        1540 FORESTVILLE RD    WAKE FOREST NC 27587-7608   NaN    017495
# ...                       ...                          ...   ...       ...
# 379380    2382 VALLEY DALE DR       FUQUAY VARINA NC 27526   NaN    017722
# 379382      1127 CLEARWOOD LN  FUQUAY VARINA NC 27526-2807   NaN    017780
# 379384        1125 MATISSE DR  FUQUAY VARINA NC 27526-2808   NaN    017747
# 379449      1347 COURTLAND DR        RALEIGH NC 27604-1370   NaN    017837
# 379450      1349 COURTLAND DR        RALEIGH NC 27604-1370   NaN    017829
#
#         ... STRUCTURE    SITE  TOTSTRUCTS  TOTUNITS  OLD_PARCEL_NUMBER  \
# 20      ...    1110.0  6100.0         1.0       1.0              645--
# 53      ...    1110.0  6100.0         1.0       1.0                 --
# 62      ...    1110.0  6100.0         1.0       1.0     699-00000-0000
# 90      ...    1110.0  6100.0         1.0       1.0     129-00000-0000
# 91      ...    1152.0  6100.0         1.0       1.0     266-00000-0067
# ...     ...       ...     ...         ...       ...                ...
# 379380  ...    1110.0  6100.0         1.0       1.0                 --
# 379382  ...       0.0  6100.0         1.0       0.0                 --
# 379384  ...    1110.0  6100.0         1.0       1.0                 --
# 379449  ...    1110.0  6100.0         1.0       1.0                 --
# 379450  ...    1110.0  6100.0         1.0       1.0                 --
#
#          ZIPNUM     SHAPEAREA    SHAPELEN PARCEL_PK  LAND_CODE
# 20      27502.0   8972.273327  385.927244  123369.0          R
# 53      27526.0  15618.798230  542.356426   82016.0          R
# 62      27539.0  32398.208820  772.193037  203517.0          R
# 90      27540.0   4500.131848  305.006592  138998.0          R
# 91      27587.0  41470.258470  950.437530  273189.0          R
# ...         ...           ...         ...       ...        ...
# 379380  27526.0   8084.969641  365.100103  488246.0          R
# 379382  27526.0   7079.921018  357.997605  488231.0          R
# 379384  27526.0   7079.810844  357.999880  488215.0          R
# 379449  27604.0   7337.087839  404.334931  489109.0          R
# 379450  27604.0   7816.970658  409.690679  489108.0          R
#
# [35560 rows x 59 columns]

# %%
dropped_zip.astype({'TOTAL_VALUE_ASSD': 'float'}).dtypes
group = dropped_zip.groupby(["ZIPNUM"])
group = group["TOTSALPRICE"].mean()

group = round(group.reset_index(), 0)
#group['ZIPNUM'] = group['ZIPNUM'].astype(str)
#group.to_csv('data/zip_by_sales_price_2019.csv')
data = pd.read_csv('data/zip_by_sales_price_2019.csv')
#data['ZIPNUM'] = data['ZIPNUM'].astype(float)
data['TOTSALPRICE'] = round(data['TOTSALPRICE'], -3)
data = data.merge(data1, left_on='ZIPNUM', right_on='ZIP', how='inner')
data['ZIPNUM'] = data['ZIPNUM'].astype(str)
data.dtypes
# Out:
# Unnamed: 0       int64
# ZIPNUM          object
# TOTSALPRICE      int64
# ZIP              int64
# LAT            float64
# LNG            float64
# dtype: object

# %%
map = folium.Map(location=[35.8032, -78.5661], default_zoom_start=15)
map.choropleth(geo_data="data/nc_zip_geo2.json",
             data=data, # my dataset
             columns=['ZIPNUM', 'TOTSALPRICE'],
             key_on='feature.properties.ZCTA5CE10', # this path contains zipcodes in str type, this zipcodes should match with our ZIP CODE column
             fill_color='BuPu', fill_opacity=.7, line_opacity=.2,
             legend_name='Mean Sales Price')
map
#map.save('index.html')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
marker_cluster = MarkerCluster().add_to(map) # create marker clusters

for i in range(data.shape[0]):
    location = [data['LAT'][i],data['LNG'][i]]
    tooltip = "Zipcode:{}<br> Borough: {}<br> Click for more".format(data["ZIPNUM"][i], zipcodes_agg['BOROUGH'][i])
